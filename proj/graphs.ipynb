# %% [markdown]
# # GRAPHS

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
## 2024-09-29

# %%
d = {'steps': [100, 200, 300, 400,500 ,600 ,700 , 800, 900, 1000, 1100, 1200, 1300, 1400,1500],
'Training Loss': [1.469800, 1.160300, 1.029500, 0.989100, 0.990500, 0.961900, 0.927100,0.927800,0.927000 ,0.935200,0.931100 ,0.840800,0.815100,0.802000 ,0.834200],
     'Validation Loss': [1.180672,1.044495 ,0.982846 ,0.970621,0.955462 ,0.962946 , 0.932509,0.931554 , 0.942617 ,0.915032,1.014436,0.921497 ,0.938526,0.938612,1.064949],
     'Accuracy': [0.488000, 0.565000, 0.585500, 0.577500, 0.599000, 0.591500, 0.601500,0.599500 , 0.588000,0.602000, 0.591000, 0.612500, 0.615500,0.612500 ,0.585500]}
 	 	 	
 	 	 	
run1 = pd.DataFrame(data=d)

# %%
run1.plot(x="steps", y=["Training Loss", "Validation Loss", "Accuracy"])
#        per_device_train_batch_size=28,
#[I 2024-09-29 16:09:18,980] Trial 0 finished with value: 0.591 and parameters: {'epoch': 5}. Best is trial 0 with value: 0.591.

#Learning rate: 5e-05 Accuracy: 0.591
#Epochs: 5 Accuracy: 0.591
run1.plot(x="steps", y="Accuracy")
# Out:
# <Axes: xlabel='steps'>
